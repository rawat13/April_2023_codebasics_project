# %%
# importing multiple csv files
import numpy as ny
import matplotlib.pyplot as plt
from google.colab import files
import pandas as pd
import io
 
data = files.upload()
# Out:
#      <input type="file" id="files-4d48b692-8820-421e-bb0b-697538aa5b84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d48b692-8820-421e-bb0b-697538aa5b84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import glob
 
# list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['foreign_visitors_2017.csv',
#  'foreign_visitors_2016.csv',
#  'foreign_visitors_2019.csv',
#  'foreign_visitors_2018.csv']

# %%
foreign_visitor_16to19 = pd.DataFrame()
 
# append the CSV files
for file in csv_files:
    df = pd.read_csv(file)
    foreign_visitor_16to19 = foreign_visitor_16to19.append(df, ignore_index=True)
 
foreign_visitor_16to19
# Out:
# <ipython-input-3-9abee68118be>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   foreign_visitor_16to19 = foreign_visitor_16to19.append(df, ignore_index=True)
# <ipython-input-3-9abee68118be>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   foreign_visitor_16to19 = foreign_visitor_16to19.append(df, ignore_index=True)
# <ipython-input-3-9abee68118be>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   foreign_visitor_16to19 = foreign_visitor_16to19.append(df, ignore_index=True)
# <ipython-input-3-9abee68118be>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df = foreign_visitor_16to19
df.head()
# Out:
#    district        date     month  year visitors
# 0  Adilabad  01-01-2017   January  2017        5
# 1  Adilabad  01-02-2017  February  2017        0
# 2  Adilabad  01-03-2017     March  2017        0
# 3  Adilabad  01-04-2017     April  2017        0
# 4  Adilabad  01-05-2017       May  2017        0

# %%
df.shape
# Out:
# (1512, 5)

# %%
df.to_excel(r"foreign_visitors_16to19.xlsx")
